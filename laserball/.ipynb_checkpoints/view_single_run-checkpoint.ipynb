# %%
import numpy as np
import awkward as ak
import uproot
import mplhep as hep
import matplotlib as mpl
import matplotlib.pyplot as plt
from tqdm import tqdm, trange
from pathlib import Path

# %load_ext autoreload
# %autoreload 2
import laserball_analysis as ana

hep.styles.use("ROOT")

# %%
run_num = 46
trees = f"/nfs/disk1/eos/gold_run_ntuples/run{run_num}/*.ntuple.root:output"
pmtinfo = ana.PMTInfo(f'/nfs/disk1/eos/gold_run_ntuples/run{run_num}/eos_data-deployed_source-laserball-run-{run_num}.0.ntuple.root')

tofs = pmtinfo.time_of_flight(np.asarray([0, 0, 0]))


def get_tresid(batch):
    return batch['fitTime'] - [tofs[ev] for ev in batch['digitPMTID']]-10.5


bins, edges = ana.aggregate_histogram(trees, branch_name=get_tresid,
                                      expressions=["fitTime", "digitNCrossings", "digitPMTID"],
                                      bin_params={"bins": np.arange(-100, 100)},
                                      cut_func=lambda batch: batch['digitNCrossings'] == 1)
hep.histplot(bins, edges)
plt.title(f"Run {run_num}")
plt.axvline(0.0, color='k')
plt.xlabel("Fit Time - TOF")
# Out:
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:09<00:00, 11065.56event/s]
# Text(1, 0, 'Fit Time - TOF')

# %%
run_num = 46
trees = f"/nfs/disk1/eos/gold_run_ntuples/run{run_num}/*.ntuple.root:output"
pmtinfo = ana.PMTInfo(f'/nfs/disk1/eos/gold_run_ntuples/run{run_num}/eos_data-deployed_source-laserball-run-{run_num}.0.ntuple.root')


bins, edges = ana.aggregate_histogram(trees, branch_name='digitPeak',
                                      expressions=["digitPeak", "digitNCrossings"],
                                      bin_params={"bins": np.arange(-100, 100)},
                                      cut_func=lambda batch: batch['digitNCrossings'] == 1)
hep.histplot(bins, edges)
plt.title(f"Run {run_num}")
plt.axvline(0.0, color='k')
# Out:
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:   0%|▎                                                                                                                                                                    | 200/100000 [00:16<2:21:09, 11.78event/s]
#
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:   2%|██▉                                                                                                                                                                | 1800/100000 [00:00<00:07, 12855.86event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:   4%|██████▏                                                                                                                                                            | 3800/100000 [00:00<00:05, 16169.93event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:   6%|█████████▍                                                                                                                                                         | 5800/100000 [00:00<00:05, 17393.45event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:   8%|████████████▋                                                                                                                                                      | 7800/100000 [00:00<00:05, 18021.81event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  10%|███████████████▉                                                                                                                                                   | 9800/100000 [00:00<00:04, 18421.55event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  12%|███████████████████                                                                                                                                               | 11800/100000 [00:00<00:05, 16009.63event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  14%|██████████████████████                                                                                                                                            | 13600/100000 [00:00<00:05, 16546.64event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  16%|█████████████████████████▎                                                                                                                                        | 15600/100000 [00:00<00:04, 17403.15event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  18%|████████████████████████████▌                                                                                                                                     | 17600/100000 [00:01<00:04, 17970.28event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  20%|███████████████████████████████▊                                                                                                                                  | 19600/100000 [00:01<00:05, 15875.02event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  22%|██████████████████████████████████▉                                                                                                                               | 21600/100000 [00:01<00:04, 16816.74event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  24%|██████████████████████████████████████▏                                                                                                                           | 23600/100000 [00:01<00:04, 17410.88event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  26%|█████████████████████████████████████████▍                                                                                                                        | 25600/100000 [00:01<00:04, 17986.67event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  28%|████████████████████████████████████████████▋                                                                                                                     | 27600/100000 [00:01<00:04, 15917.11event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  30%|███████████████████████████████████████████████▉                                                                                                                  | 29600/100000 [00:01<00:04, 16855.37event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  32%|███████████████████████████████████████████████████▏                                                                                                              | 31600/100000 [00:01<00:03, 17521.94event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  34%|██████████████████████████████████████████████████████▍                                                                                                           | 33600/100000 [00:01<00:03, 18098.54event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  36%|█████████████████████████████████████████████████████████▋                                                                                                        | 35600/100000 [00:02<00:04, 16014.98event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  38%|████████████████████████████████████████████████████████████▉                                                                                                     | 37600/100000 [00:02<00:03, 16846.40event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  40%|████████████████████████████████████████████████████████████████▏                                                                                                 | 39600/100000 [00:02<00:03, 17581.68event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  42%|███████████████████████████████████████████████████████████████████▍                                                                                              | 41600/100000 [00:02<00:03, 18151.92event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  44%|██████████████████████████████████████████████████████████████████████▋                                                                                           | 43600/100000 [00:02<00:03, 16002.66event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  46%|█████████████████████████████████████████████████████████████████████████▊                                                                                        | 45600/100000 [00:02<00:03, 16853.40event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  48%|█████████████████████████████████████████████████████████████████████████████                                                                                     | 47600/100000 [00:02<00:02, 17498.66event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  50%|████████████████████████████████████████████████████████████████████████████████▎                                                                                 | 49600/100000 [00:02<00:02, 18068.57event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  52%|███████████████████████████████████████████████████████████████████████████████████▌                                                                              | 51600/100000 [00:03<00:03, 16028.90event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  54%|██████████████████████████████████████████████████████████████████████████████████████▊                                                                           | 53600/100000 [00:03<00:02, 16871.74event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  56%|██████████████████████████████████████████████████████████████████████████████████████████                                                                        | 55600/100000 [00:03<00:02, 17601.50event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  58%|█████████████████████████████████████████████████████████████████████████████████████████████▎                                                                    | 57600/100000 [00:03<00:02, 18142.88event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  60%|████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                 | 59600/100000 [00:03<00:02, 18503.23event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  62%|███████████████████████████████████████████████████████████████████████████████████████████████████▊                                                              | 61600/100000 [00:03<00:02, 16186.07event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  64%|███████████████████████████████████████████████████████████████████████████████████████████████████████                                                           | 63600/100000 [00:03<00:02, 16955.08event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  66%|██████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                       | 65600/100000 [00:03<00:01, 17612.42event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  68%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                                                    | 67600/100000 [00:03<00:01, 18134.87event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  70%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                                                 | 69600/100000 [00:04<00:01, 15911.21event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  72%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                              | 71600/100000 [00:04<00:01, 16762.78event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  74%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                          | 73600/100000 [00:04<00:01, 17493.89event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  76%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                       | 75600/100000 [00:04<00:01, 17906.00event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  78%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                                    | 77600/100000 [00:04<00:01, 15860.91event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  80%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                                 | 79600/100000 [00:04<00:01, 16744.11event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                             | 81600/100000 [00:04<00:01, 17394.03event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                          | 83600/100000 [00:04<00:00, 17932.03event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                       | 85600/100000 [00:05<00:00, 15932.05event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                    | 87600/100000 [00:05<00:00, 16784.67event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  90%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                | 89600/100000 [00:05<00:00, 17531.50event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  92%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍             | 91600/100000 [00:05<00:00, 18067.03event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋          | 93600/100000 [00:05<00:00, 15928.89event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  96%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊       | 95600/100000 [00:05<00:00, 16777.56event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output:  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████    | 97600/100000 [00:05<00:00, 17339.64event/s]
#
#
# /nfs/disk1/eos/gold_run_ntuples/run46/*.ntuple.root:output: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 100000/100000 [00:05<00:00, 17100.70event/s]

# %%
trees = "/nfs/disk1/users/jierans/eos/eos_laserball_sims/eos_pbomb_514nm_0_down.ntuple.root:output"

def get_tresid(batch):
    return batch['fitTime'] - [tofs[ev] for ev in batch['digitPMTID']]


bins, edges = ana.aggregate_histogram(trees, branch_name=get_tresid,
                                      expressions=["fitTime", "digitNCrossings", "digitPMTID"],
                                      bin_params={"bins": np.arange(-100, 100)},
                                      cut_func=lambda batch: batch['digitNCrossings'] == 1)
hep.histplot(bins, edges)
plt.title("MC")
plt.axvline(0.0, color='k')
plt.xlabel("Fit Time - TOF")
# Out:
# /nfs/disk1/users/jierans/eos/eos_laserball_sims/eos_pbomb_514nm_0_down.ntuple.root:output: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 250000/250000 [00:07<00:00, 33365.04event/s]
# Text(1, 0, 'Fit Time - TOF')
